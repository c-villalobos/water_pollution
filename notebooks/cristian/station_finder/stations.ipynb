# %% [markdown]
# # Stations database

# %% [markdown]
# Tap keyword in placeholder ("MIRIBEL") e.g.: "LYON", "SAONE".

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stations = pd.read_csv('../../raw_data/stations.csv', sep = ';', error_bad_lines = False)
# Out:
# b'Skipping line 11160: expected 39 fields, saw 40\nSkipping line 13459: expected 39 fields, saw 40\nSkipping line 16011: expected 39 fields, saw 40\nSkipping line 16316: expected 39 fields, saw 41\n'
# b'Skipping line 17124: expected 39 fields, saw 40\n'

# %%
stations[stations['LbStationMesureEauxSurface'].str.contains("LYON") == True]
# Out:
#       CdStationMesureEauxSurface                 LbStationMesureEauxSurface  \
# 16                      04009700               ANZIEUX à CHAZELLES-SUR-LYON
# 531                     04009080                 COISE à CHAZELLES-SUR-LYON
# 1636                    04406014            RAU GIMOND A CHAZELLES-SUR-LYON
# 1770                    06002057                GORGES DE LA DUCHERE A LYON
# 1964                    06059500                             SAONE A LYON 1
# 1966                    06059550                             SAONE A LYON 2
# 2053                    06093340                 YZERON A STE-FOY-LES-LYON
# 4673                    06213250                 RUISSEAU DE L'ARCHE A LYON
# 4677                    06213340                  RUISSEAU DE LITTRE A LYON
# 4687                    06213680              RUISSEAU DE CHARBOTTES A LYON
# 5589                    04406042      RAU DE L'ANXIEUX A CHAZELLES-SUR-LYON
# ...

# %%
stations.columns
# Out:
# Index(['CdStationMesureEauxSurface', 'LbStationMesureEauxSurface',
#        'DurStationMesureEauxSurface', 'CoordXStationMesureEauxSurface',
#        'CoordYStationMesureEauxSurface', 'CdProjStationMesureEauxSurface',
#        'LibelleProjection', 'CodeCommune', 'LbCommune', 'CodeDepartement',
#        'LbDepartement', 'CodeRegion', 'LbRegion', 'CdMasseDEau',
#        'CdEuMasseDEau', 'NomMasseDEau', 'CdEuSsBassinDCEAdmin',
#        'NomSsBassinDCEAdmin', 'CdBassinDCE', 'CdEuBassinDCE', 'NomEuBassinDCE',
#        'CdTronconHydrographique', 'CdCoursdEau', 'NomCoursdEau',
#        'CodeTypEthStationMesureEauxSurface',
#        'LibelleTypEthStationMesureEauxSurface', 'ComStationMesureEauxSurface',
#        'DateCreationStationMesureEauxSurface',
#        'DateArretActiviteStationMesureEauxSurface',
#        'DateMAJInfosStationMesureEauxSurface',
#        'FinaliteStationMesureEauxSurface',
#        'LocPreciseStationMesureEauxSurface',
#        'CodeNatureStationMesureEauxSurface',
# ...

# %%
stations.shape
# Out:
# (20965, 39)
