# %%
import pandas as pd

# %%
faune_df = pd.read_csv("../../raw_data/bio_caluire_2011_2021/ResultatsBiologiques.CSV", sep=';', error_bad_lines=False)
# Out:
# /home/sve/.pyenv/versions/3.8.12/envs/water_pollution/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# **Champs utiles :**
#
#
# **CdStationMesureEauxSurface** : id unique de la station de mesure
# **LbStationMesureEauxSurface** : libellé de la station
# **DateDebutOperationPrelBio** : date du prelevement
#
# **LbLongParametre** : libellé du paramètre (type de mesure)
# **ResIndiceResultatBiologique** : résultat de la mesure
# **CdUniteMesure** : unité du résultat de mesure
# **SymUniteMesure** : symbole de l'unité de mesure
#
#
# **CdSupport** : id du 'support', pour faire un joint éventuelle avec une autre table (opération / faune flore)

# %%
faune_df.shape
# Out:
# (95, 21)

# %%
selected_col = [
    'CdStationMesureEauxSurface',
    'LbStationMesureEauxSurface',
    'DateDebutOperationPrelBio',
    'LbLongParametre',
    'ResIndiceResultatBiologique',
    'SymUniteMesure',
    'CdSupport',
]

# Filtre sur les champs sélectionnés
faune_df = faune_df[selected_col]

# %%
faune_df
# Out:
#     CdStationMesureEauxSurface LbStationMesureEauxSurface  \
# 0                      6059500             SAONE A LYON 1
# 1                      6059500             SAONE A LYON 1
# 2                      6059500             SAONE A LYON 1
# 3                      6059500             SAONE A LYON 1
# 4                      6059500             SAONE A LYON 1
# ..                         ...                        ...
# 90                     6059500             SAONE A LYON 1
# 91                     6059500             SAONE A LYON 1
# 92                     6059500             SAONE A LYON 1
# 93                     6059500             SAONE A LYON 1
# 94                     6059500             SAONE A LYON 1
#
#    DateDebutOperationPrelBio  \
# 0                 2013-09-02
# 1                 2013-09-02
# 2                 2013-09-02
# 3                 2013-09-02
# 4                 2013-09-02
# ..                       ...
# 90                2015-09-04
# 91                2017-08-23
# 92                2019-08-13
# 93                2019-08-13
# 94                2019-08-13
#
#                                       LbLongParametre  \
# 0                        Indice Poisson Rivière (IPR)
# 1   Score de la métrique nombre total d’espèces (NTE)
# 2   Score de la métrique nombre d'espèces lithophi...
# 3   Score de la métrique nombre d'espèces rhéophil...
# 4   Score de la métrique densité d'individus inver...
# ..                                                ...
# 90  Indice Biologique Macrophytique en Rivière (I....
# 91  Indice Biologique Macrophytique en Rivière (I....
# 92  Indice Biologique Macrophytique en Rivière (I....
# 93            Nombre de taxons contributifs de l'IBMR
# 94                                  Note IBMR robuste
#
#     ResIndiceResultatBiologique SymUniteMesure  CdSupport
# 0                     13.404967              X          4
# 1                      0.165323              X          4
# 2                      1.543284              X          4
# 3                      9.010050              X          4
# 4                      0.050489              X          4
# ..                          ...            ...        ...
# 90                     7.500000              n         27
# 91                     7.250000              n         27
# 92                     7.310000              n         27
# 93                    17.000000              n         27
# 94                     7.210000              n         27
#
# [95 rows x 7 columns]

# %%
faune_df.groupby('LbLongParametre')[['CdStationMesureEauxSurface']].count().sort_values('CdStationMesureEauxSurface')
# Out:
#                                                     CdStationMesureEauxSurface
# LbLongParametre
# Note IBMR robuste                                                            1
# Nombre de taxons contributifs de l'IBMR                                      1
# Nombre d'unités diatomiques contributives                                    3
# Score de la métrique nombre total d’espèces (NTE)                            4
# Score de la métrique nombre d'espèces rhéophile...                           4
# Indice Biologique Macrophytique en Rivière (I.B...                           4
# Indice Poisson Rivière (IPR)                                                 4
# Score de la métrique nombre d'espèces lithophil...                           4
# Score de la métrique densité totale d'individus...                           4
# Score de la métrique densité d'individus toléra...                           4
# Score de la métrique densité d'individus invert...                           4
# Score de la métrique densité d'individus omnivo...                           4
# Variété taxonomique macroinvertébrés grands cou...                           6
# Indice macroinvertébrés grands cours d'eau - be...                           6
# Groupe Faunistique Indicateur macroinvertébrés ...                           6
# Indice macroinvertébrés grands cours d'eau - 12...                           9
# Indice Biologique Diatomées (IBD)                                            9
# Variété taxonomique macroinvertébrés grands cou...                           9
# Groupe Faunistique Indicateur macroinvertébrés ...                           9

# %%
filtered_col = 'LbLongParametre'
filtered_mesure = "Indice macroinvertébrés grands cours d'eau - 12 prélèvements"

faune_df = faune_df[faune_df[filtered_col] == filtered_mesure]

# %%
faune_df
# Out:
#     CdStationMesureEauxSurface LbStationMesureEauxSurface  \
# 45                     6059500             SAONE A LYON 1
# 51                     6059500             SAONE A LYON 1
# 57                     6059500             SAONE A LYON 1
# 63                     6059500             SAONE A LYON 1
# 69                     6059500             SAONE A LYON 1
# 75                     6059500             SAONE A LYON 1
# 80                     6059500             SAONE A LYON 1
# 83                     6059500             SAONE A LYON 1
# 86                     6059500             SAONE A LYON 1
#
#    DateDebutOperationPrelBio  \
# 45                2012-09-19
# 51                2013-09-13
# 57                2014-07-03
# 63                2015-06-19
# 69                2016-07-29
# 75                2017-07-10
# 80                2018-07-12
# 83                2019-07-25
# 86                2020-06-19
#
#                                       LbLongParametre  \
# 45  Indice macroinvertébrés grands cours d'eau - 1...
# 51  Indice macroinvertébrés grands cours d'eau - 1...
# 57  Indice macroinvertébrés grands cours d'eau - 1...
# 63  Indice macroinvertébrés grands cours d'eau - 1...
# 69  Indice macroinvertébrés grands cours d'eau - 1...
# 75  Indice macroinvertébrés grands cours d'eau - 1...
# 80  Indice macroinvertébrés grands cours d'eau - 1...
# 83  Indice macroinvertébrés grands cours d'eau - 1...
# 86  Indice macroinvertébrés grands cours d'eau - 1...
#
#     ResIndiceResultatBiologique SymUniteMesure  CdSupport
# 45                         14.0              n         13
# 51                         14.0              n         13
# 57                         13.0              n         13
# 63                         13.0              n         13
# 69                         10.0              n         13
# 75                         15.0              n         13
# 80                         13.0              n         13
# 83                          9.0              n         13
# 86                         10.0              n         13
