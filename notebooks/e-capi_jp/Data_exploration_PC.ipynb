# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_2011_PC = pd.read_csv("/home/ecapi/code/sebvey/water_pollution/raw_data/PC-2011.CSV", sep=";")

# %%
df_2011_PC.shape
# Out:
# (6616, 51)

# %%
df_2011_PC.head(5)
# Out:
#    CdStationMesureEauxSurface LbStationMesureEauxSurface  CdSupport LbSupport  \
# 0                     6059500             SAONE A LYON 1          3       Eau
# 1                     6059500             SAONE A LYON 1          3       Eau
# 2                     6059500             SAONE A LYON 1          3       Eau
# 3                     6059500             SAONE A LYON 1          3       Eau
# 4                     6059500             SAONE A LYON 1          3       Eau
#
#    CdFractionAnalysee LbFractionAnalysee  CdPrelevement    DatePrel HeurePrel  \
# 0                  23          Eau brute         537037  2011-11-22  14:40:00
# 1                  23          Eau brute         537037  2011-11-22  14:40:00
# 2                  23          Eau brute         537037  2011-11-22  14:40:00
# 3                  23          Eau brute         537037  2011-11-22  14:40:00
# 4                  23          Eau brute         537037  2011-11-22  14:40:00
#
#    DateAna  ...  CommentairesAna  ComResultatAna CdRdd  NomRdd  \
# 0      NaN  ...              NaN             NaN   NaN     NaN
# 1      NaN  ...              NaN             NaN   NaN     NaN
# 2      NaN  ...              NaN             NaN   NaN     NaN
# 3      NaN  ...              NaN             NaN   NaN     NaN
# 4      NaN  ...              NaN             NaN   NaN     NaN
#
#      CdProducteur                           NomProducteur     CdPreleveur  \
# 0  18690155900069  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 1  18690155900069  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 2  18690155900069  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 3  18690155900069  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
# 4  18690155900069  AGENCE EAU RHONE MEDITERRANEE ET CORSE  41054531300042
#
#                                         NomPreleveur   CdLaboratoire  \
# 0  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 1  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 2  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 3  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
# 4  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...  41054531300042
#
#                                       NomLaboratoire
# 0  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 1  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 2  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 3  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
# 4  CARSO - LABORATOIRE SANTE ENVIRONNEMENT HYGIEN...
#
# [5 rows x 51 columns]

# %%
# Out:
# array([1082, 1083, 1089, 1090, 1091, 1092, 1093, 1094, 1101, 1102, 1103,
#        1104, 1105, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115,
#        1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126,
#        1127, 1128, 1129, 1130, 1131, 1133, 1134, 1135, 1136, 1137, 1139,
#        1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1153,
#        1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1164, 1165,
#        1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1175, 1176, 1177,
#        1178, 1179, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189,
#        1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1199, 1200, 1201,
#        1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1212, 1213,
#        1214, 1215, 1216, 1217, 1218, 1221, 1222, 1225, 1226, 1227, 1228,
#        1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240,
#        1241, 1242, 1243, 1244, 1245, 1246, 1253, 1254, 1255, 1256, 1257,
#        1258, 1259, 1260, 1261, 1262, 1263, 1264, 1266, 1267, 1268, 1269,
#        1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1280, 1281,
#        1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293,
#        1294, 1295, 1301, 1302, 1303, 1305, 1308, 1310, 1311, 1312, 1313,
#        1314, 1319, 1329, 1333, 1336, 1341, 1350, 1353, 1359, 1360, 1402,
#        1403, 1405, 1406, 1414, 1432, 1453, 1456, 1458, 1463, 1464, 1465,
#        1467, 1468, 1469, 1470, 1471, 1473, 1474, 1476, 1480, 1486, 1488,
#        1490, 1491, 1492, 1493, 1494, 1495, 1497, 1498, 1500, 1501, 1502,
#        1503, 1504, 1506, 1510, 1511, 1513, 1515, 1516, 1517, 1519, 1520,
#        1521, 1522, 1523, 1524, 1525, 1526, 1528, 1529, 1531, 1532, 1533,
#        1534, 1535, 1537, 1538, 1540, 1544, 1548, 1549, 1550, 1577, 1578,
#        1579, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593,
#        1594, 1595, 1600, 1601, 1602, 1603, 1604, 1605, 1607, 1612, 1613,
#        1614, 1615, 1616, 1617, 1618, 1619, 1621, 1622, 1623, 1624, 1625,
#        1626, 1627, 1628, 1629, 1630, 1631, 1633, 1635, 1636, 1637, 1638,
#        1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649,
#        1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660,
#        1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671,
#        1672, 1673, 1674, 1675, 1676, 1678, 1679, 1680, 1681, 1682, 1683,
#        1684, 1685, 1686, 1687, 1688, 1694, 1696, 1697, 1698, 1699, 1700,
#        1702, 1704, 1706, 1707, 1709, 1710, 1711, 1712, 1713, 1714, 1715,
#        1718, 1719, 1722, 1727, 1742, 1744, 1748, 1749, 1753, 1757, 1762,
#        1763, 1764, 1765, 1796, 1797, 1802, 1805, 1806, 1807, 1809, 1810,
#        1812, 1813, 1814, 1815, 1825, 1829, 1830, 1831, 1832, 1834, 1835,
#        1840, 1847, 1850, 1854, 1859, 1860, 1861, 1862, 1863, 1864, 1865,
#        1866, 1870, 1871, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881,
#        1882, 1883, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895,
#        1896, 1897, 1898, 1900, 1901, 1902, 1903, 1905, 1906, 1907, 1908,
#        1909, 1910, 1911, 1912, 1913, 1914, 1920, 1923, 1929, 1930, 1936,
#        1937, 1939, 1941, 1942, 1945, 1949, 1950, 1951, 1952, 1954, 1955,
#        1958, 1959, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026,
#        2027, 2028, 2029, 2032, 2045, 2046, 2047, 2056, 2057, 2064, 2065,
#        2068, 2069, 2070, 2071, 2074, 2075, 2076, 2081, 2082, 2085, 2087,
#        2093, 2095, 2096, 2534, 2536, 2537, 2542, 2544, 2545, 2546, 2547,
#        2563, 2565, 2567, 2568, 2576, 2578, 2609, 2610, 2611, 2664, 2669,
#        2678, 2715, 2722, 2729, 2732, 2734, 2735, 2737, 2742, 2743, 2745,
#        2746, 2747, 2748, 2749, 2750, 2751, 2752, 2753, 2754, 2755, 2759,
#        2773, 2810, 2826, 2847, 2858, 2860, 2870, 2871, 2872, 2873, 2879,
#        2885, 2886, 2887, 2888, 2889, 2890, 2898, 2911, 2912, 2913, 2915,
#        2916, 2919, 2920, 2924, 2925, 2933, 2937, 2950, 2951, 2966, 2974,
#        2976, 2977, 2981, 2982, 2985, 2990, 2992, 3209, 5249, 5416, 5474,
#        5475, 5476, 5477, 5478, 5481, 5523, 5524, 5525, 5526, 5528, 5531,
#        5532, 5554, 5579, 5603, 5619, 5648, 5654, 5842, 5930, 5968, 5970,
#        5971, 6102, 6214, 6342, 6372, 6390, 6393, 6394, 6398, 6399, 6530,
#        6534, 6539, 6601, 6616, 7010, 7017, 7074, 1327, 1328, 1345, 1346,
#        1347, 1436, 1439, 1332, 1335, 1339, 1340, 1348, 1361, 1362, 1368,
#        1369, 1373, 1376, 1377, 1379, 1380, 1382, 1383, 1384, 1385, 1386,
#        1387, 1388, 1389, 1392, 1395, 1396, 1433, 1841, 2555, 2559, 1337,
#        1338, 1367, 1372, 1374, 1375, 1198, 1370, 1393, 1394, 1487, 1606,
#        1723, 1799, 1921, 1957, 2736, 3054, 5432, 5433, 5434, 5435, 5436,
#        5437, 5539, 6228, 6578, 7042, 7043, 7044])

# %% [markdown]
# ### All Columns in the DB

# %%
df_2011_PC.columns.unique()
# Out:
# Index(['CdStationMesureEauxSurface', 'LbStationMesureEauxSurface', 'CdSupport',
#        'LbSupport', 'CdFractionAnalysee', 'LbFractionAnalysee',
#        'CdPrelevement', 'DatePrel', 'HeurePrel', 'DateAna', 'HeureAna',
#        'CdParametre', 'LbLongParamètre', 'RsAna', 'CdUniteMesure',
#        'SymUniteMesure', 'CdRqAna', 'MnemoRqAna', 'CdInsituAna', 'LbInsituAna',
#        'ProfondeurPrel', 'CdDifficulteAna', 'MnemoDifficulteAna', 'LdAna',
#        'LqAna', 'LsAna', 'IncertAna', 'CdMetFractionnement',
#        'NomMetFractionnement', 'CdMethode', 'NomMethode', 'RdtExtraction',
#        'CdMethodeExtraction', 'NomMethodeExtraction', 'CdAccreAna',
#        'MnemoAccredAna', 'AgreAna', 'CdStatutAna', 'MnemoStatutAna',
#        'CdQualAna', 'LbQualAna', 'CommentairesAna', 'ComResultatAna', 'CdRdd',
#        'NomRdd', 'CdProducteur', 'NomProducteur', 'CdPreleveur',
#        'NomPreleveur', 'CdLaboratoire', 'NomLaboratoire'],
#       dtype='object')

# %%
len(df_caluire.columns.unique())
# Out:
# 51

# %%
params_to_analyse_list = list(df_caluire.LbLongParamètre.unique())
params_to_analyse_list
# Out:
# ['Propiconaz',
#  'Conductiv.',
#  'Parath. M',
#  'Be',
#  'DNitCrésol',
#  'DBO5',
#  'Méthabenzt',
#  'Endosuf.a',
#  'B(a)A',
#  'HyfopMet-R',
#  'DEHP',
#  'Cyprodinil',
#  'Acenaphten',
#  'Promécarbe',
#  'Pyrène',
#  'Alpha-cype',
#  'MES',
#  'Biphényle',
#  'Bioresméth',
#  'phosmet',
#  'PHEOPIG.',
#  'Mévinphos',
#  '2ClToluène',
#  'Ba',
#  'Cr',
#  '3ClAniline',
#  'Flurochlor',
#  'Chlorbromu',
#  'ChlordaneA',
#  '25DClAnili',
#  'Toluene',
#  'O2 dissous',
#  'NH4+',
#  'Aldrine',
#  'Xylène-p',
#  '2Cl6metPh',
#  'Carbofuran',
#  'V',
#  'Cu',
#  'Dichlorob',
#  'ClBenzyle',
#  'Phosphamid',
#  'Krésoxym',
#  '2,3,4-3CPh',
#  "DDT 24'",
#  'dithianon',
#  'Disulfoton',
#  'Chloronèbe',
#  'Bromoph. M',
#  'Ethopropho',
#  'pH',
#  'Coumatétra',
#  'PBDE138',
#  '2,5 DCPhén',
#  'TCB 135',
#  '2,4DiClPhe',
#  'Co',
#  'DFlubenzur',
#  'P total',
#  'Pb',
#  'Dicofol',
#  'Cd',
#  'AMPA',
#  '2.4-MCPB',
#  'Linuron',
#  'Méthomyl',
#  'Fluoranth.',
#  'Terbutryne',
#  '1Cl24DNB',
#  'Formothion',
#  '245 TCPhen',
#  'Ethidimuro',
#  '1,2DCP',
#  'Parath. E',
#  'DBrom Ethn',
#  'Prochloraz',
#  'Enodrin',
#  'Tébuco.',
#  'Pyrimiph.M',
#  'Tributyl P',
#  '1.2-2ClEth',
#  'Tétradifon',
#  '2,3,5-3CPh',
#  'Diuron',
#  'Xylène-m',
#  '4ClAniline',
#  'PCB 118',
#  'Propoxur',
#  'Orthophosp',
#  'Fenthion',
#  'Desmétryne',
#  'Ofurace',
#  'Bifenthrin',
#  'Tolylfluan',
#  'Cypronazol',
#  'Hg',
#  'Quinoxyfen',
#  '1235ClBz',
#  'Chlorfenvi',
#  'Dioctylsta',
#  'B',
#  'HCHepsilon',
#  '2,4DClNBe',
#  'CNitBenz P',
#  '2,3 DCProp',
#  'As',
#  'Amétryne',
#  'Fluorène',
#  'Monolinuro',
#  'Benzo(b)fl',
#  'Temp. eau',
#  'Procymidon',
#  'Lufénuron',
#  'NO2-',
#  'Triazophos',
#  'Me2 Napht.',
#  'Sulfotep',
#  '2ClAniline',
#  'Oxadixyl',
#  'Azaconazol',
#  'Carbendaz.',
#  'Chlorméph.',
#  'Naled',
#  'Desmethyln',
#  '2,6 DCPhén',
#  'CHL.A',
#  'Ni',
#  'Butraline',
#  'PCB 105',
#  'Anthracène',
#  'Diméfuron',
#  'Na',
#  'Zn',
#  'Pyrazophos',
#  'HCO3-',
#  'Bentazone',
#  '5BDEMIX',
#  'Captafol',
#  'DCProp-1.3',
#  'Norflurazo',
#  "DDD 24'",
#  'Benzo(k)fl',
#  'Mg',
#  'Métolachlo',
#  'Iodofenpho',
#  '35DClAnili',
#  'Tebufenpyr',
#  'PCB 101',
#  'Monuron',
#  'Epoxcz',
#  'TCB 123',
#  'DB(ah)anth',
#  'terbutdes',
#  'Carbétamid',
#  'Méthidat.',
#  'PCB 194',
#  'aminochlor',
#  'Dimétilan',
#  '2Cl-5MPhé',
#  'Chrysène',
#  'Indénopyr.',
#  'Octylstann',
#  'Dichloflua',
#  'Me2Fluor.',
#  'Chlortolu',
#  'Heptachlor',
#  'Propanil',
#  'Benz(ghi)P',
#  '1.2-2ClBnz',
#  'HCH gamma',
#  'XYLENE',
#  '2,4DMetPh',
#  'Bromacil',
#  'Diméthylam',
#  'HCBu',
#  'SO4--',
#  '26DClAnili',
#  'Coumaphos',
#  '2,3,6-3CPh',
#  'K',
#  'C Orga',
#  'Diazinon',
#  'TTCE',
#  'mefenacet',
#  'TributSn',
#  '2nitrophé',
#  'Bénomyl',
#  'Benzo(a)py',
#  'TCB 124',
#  'Sb',
#  'Secbuméton',
#  'Mercaptodi',
#  'Isoprotu.',
#  'SATUR.O2',
#  'Phoxime',
#  'Triazamate',
#  'Terbacil',
#  'Pyridabène',
#  'Dieldrine',
#  'Oryzalin',
#  '2ClNapht.',
#  'Mept Dinoc',
#  '1.4-2ClBnz',
#  'isazofos',
#  'Acénaphtyl',
#  'Azoxystro',
#  'Flufenoxur',
#  '4ClToluène',
#  '1.3-2ClBnz',
#  "DDD 44'",
#  'Chinométhi',
#  'Dichlobeni',
#  'HCH alpha',
#  'NO3-',
#  'Ferbam',
#  '12DCEtn C',
#  'Isofenphos',
#  '26DNtoluèn',
#  'Propachlor',
#  'propaquiza',
#  'Imidaclopr',
#  'HCH bêta',
#  'PCB 52',
#  '4-CPhénol',
#  'Bromadiolo',
#  'EPTC',
#  'Bifénox',
#  '2,3,5-Tric',
#  'Flusilazol',
#  '3,4-DCPU',
#  'AzinphosE',
#  '12DCEtnSom',
#  'Isodrine',
#  'PBDE153',
#  'Propétamph',
#  'Simazine',
#  'Bitertanol',
#  'Flurprimid',
#  '8BDEMIX',
#  '245ClAnili',
#  'CHCl3',
#  'HeptachlEp',
#  '4Cl-3MPhé',
#  'Propargite',
#  'BDE100',
#  'HCH delta',
#  'Fipronil',
#  'Métazachlo',
#  'Téflubenzu',
#  '4ClNO3Tolu',
#  'DIA',
#  'ClThalonil',
#  'EtChlorpy',
#  'CNitBenz O',
#  'Phénanthr.',
#  'Métribuzin',
#  '1245 TTCB',
#  'Dinosèbe',
#  'Dichlorvos',
#  'naptalame',
#  'Pencycuron',
#  '34DClAnili',
#  'BDE209',
#  'TAC',
#  '24D',
#  'Isoxaben',
#  'Glyphosate',
#  'Néburon',
#  'Diallate',
#  '3-MetPh',
#  'Dichlorpro',
#  'Ethylbenz.',
#  'TTCLPH2345',
#  'Oxadiazon',
#  'ClBenzylid',
#  'Fenpropimo',
#  'Triadiméf.',
#  'Iprodione',
#  '1ClNapht.',
#  'Benzidine',
#  'Napropamid',
#  '2,4,5-T',
#  'Myclobutan',
#  'Ethion',
#  'Pyrimiph.E',
#  'Clomazone',
#  'Atraz dés',
#  'TetrButTin',
#  'Mo',
#  'Isoxafluto',
#  'Aldicarbe',
#  'TCA 1.1.1',
#  'Pyriméthan',
#  'Difénocona',
#  'Dinoterbe',
#  'Fenpropat',
#  'Captane',
#  'Buprofézin',
#  'Terbuphos',
#  'Fludioxoni',
#  'Ti',
#  'Mécoprop',
#  '2.4-MCPA',
#  'Métobromur',
#  'Famoxadone',
#  '3ClToluène',
#  'Tralométhr',
#  'Mobutytin+',
#  'Cl-',
#  'F-',
#  'Acétochlor',
#  '1.1-2ClEtn',
#  'NKJ',
#  'Fénitroth.',
#  'TTCLPH2356',
#  'Cyanazine',
#  'cis-Cldane',
#  '3-CPhénol',
#  'TCE',
#  'Chlorophac',
#  'Aminotriaz',
#  'Ethofumés',
#  'ClBenzene',
#  'Temephos',
#  'Chloridazo',
#  'Diméthomor',
#  'CPhénol-2',
#  'Se',
#  'Endrine',
#  'Thallium',
#  'Dimethamid',
#  'TCA 1.1.2',
#  'Fluvalinat',
#  '24DClAnili',
#  'Te',
#  'Phenyltin',
#  'Bromoph. E',
#  'asulame',
#  '24DNtoluèn',
#  'Glufo-ammo',
#  'fluridone',
#  'Profenofos',
#  '2,3DClNBe',
#  'Naphtalène',
#  'AzinphosM',
#  'Chloroxuro',
#  '3Clpropène',
#  'HCB',
#  'Flazasulfu',
#  'Chlorthiam',
#  'Quinalphos',
#  '2,5DClNBe',
#  'Thiabendaz',
#  'PCP',
#  'Depalléthr',
#  'Hexythiazo',
#  'TTCA 1122',
#  '3,5DClNBe',
#  '3,5 DCPhén',
#  '3,4 DCPhén',
#  '6ClEthane',
#  'Aclonifène',
#  'Diflufenic',
#  '246 TCPhén',
#  '3,4DClNBe',
#  'Malathion',
#  'Triadiméno',
#  '4-MetPh',
#  'Alachlore',
#  'CCl4',
#  'CNitBenz M',
#  '246TClAnil',
#  '2ClNO3Tolu',
#  'Diéthofenc',
#  'Bendiocarb',
#  '23DClAnili',
#  'Tébufénozi',
#  'Ag',
#  'Carbaryl',
#  'Pirimicarb',
#  'TTCLPH2346',
#  'Phorate',
#  'Penconazol',
#  'Prosulfoca',
#  'Benflural.',
#  'Prométone',
#  'Fénarimol',
#  '4Cl2Nanil.',
#  'Dureté',
#  '234ClAnili',
#  '2,4-D-este',
#  'Fenoxycarb',
#  'PentaClBz',
#  'Chloroprèn',
#  '2ClMéthane',
#  'Piper.buto',
#  '4CloToluid',
#  'Xylène-o',
#  'Amidosulf',
#  'Furalaxyl',
#  'Dimétachlo',
#  '24DB',
#  '2-MetPh',
#  'U',
#  '2,3 DCPhén',
#  'Chlorpyr-m',
#  'Métoxuron',
#  'Fenhexamid',
#  'Diclofop M',
#  '1,3DCP',
#  'Fenpropidi',
#  'Endosulf.b',
#  'Demeton SM',
#  'DibutSn',
#  'PCB 170',
#  'TChlordane',
#  'LdaCihalo',
#  'PCB 44',
#  '12DCEtn T',
#  'Phosalone',
#  'Thifensulf',
#  'Ca',
#  'Pendiméth.',
#  '1.1-2ClEth',
#  'Quintozène',
#  "DDT 44'",
#  'Atrazine',
#  'Métalaxyl',
#  'PCB 209',
#  'Déméton',
#  'Terbuthyl.',
#  'Sn',
#  'Heptenopho',
#  'Propazine',
#  'Imazametha',
#  '4-nonylphe',
#  'Képone',
#  'Phenmédiph',
#  'Triflumuro',
#  '4-tert-but',
#  'Thiodicarb',
#  'Terbuméton',
#  'PCB 28',
#  'Esfenvaler',
#  'Hexaconazo',
#  'Diniconazo',
#  'Quizalofop',
#  'Bromopropy',
#  'OxydémétoM',
#  'Bupirimate',
#  'Deltameth.',
#  'Méthoxychl',
#  'Diphenylti',
#  'Perméthrin',
#  'PBDE99',
#  'Métosulame',
#  'Triocttin+',
#  'Ométhoate',
#  'Tricyhtin+',
#  'PCB 138',
#  'PBDE47',
#  'Chlorsulfu',
#  'Ioxynil',
#  'Fluroxypyr',
#  'TPhenSn',
#  'Fréon 113',
#  'Métamitron',
#  "DDE 44'",
#  '1-4-Isopro',
#  'Propyzamid',
#  'PCB 153',
#  'Cycluron',
#  'acifluorfe',
#  'Imazalil',
#  'C8H8Cl2N2O',
#  "DDE 24'",
#  'Ac. CAcétq',
#  'PCB 180',
#  'Diméthoate',
#  'Nonylpheno',
#  'Ethiophenc',
#  'Octylpheno',
#  'Triallate',
#  'Flurtamone',
#  'Tétrachlor',
#  'Pyrifenox',
#  'Cloq-mex',
#  'Buturon',
#  'Chl. vinyl',
#  'Lénacile',
#  'Molinate',
#  'EpiCHydrin',
#  'Cadusafos',
#  'ChlordaneG',
#  'Chlordane',
#  'Tetraconaz',
#  'Amitraz',
#  'Fonofos',
#  'Acrinathri',
#  'Clopyralid',
#  'Tébutame',
#  'Trichlorf.',
#  'Flutriafol',
#  'Sulcotrion',
#  'CProphame',
#  'Dichlofent',
#  'Fluquincon',
#  '4Clvinphos',
#  '2ClEthanol',
#  'Quiz.éthyl',
#  'Cyperméth.',
#  'Triclopyr',
#  'Cyfluthrin',
#  'Triflural.',
#  'Roténone',
#  'Nuarimol',
#  'Thiométon',
#  '2,4-D meth',
#  'Hexaflumur',
#  'Vinclozol',
#  'Cymoxanil',
#  'Chlorbufam',
#  'Endos. S',
#  'Folpel',
#  '2,4-D isop',
#  'Azamétipho',
#  'Mépronil',
#  'Benalaxyl',
#  'Dicamba',
#  'Thiazaflur',
#  'Bromuconaz',
#  'fenoxaproE',
#  'Benzène',
#  'Demet. SMS',
#  'Sebuthylaz',
#  'MetsulfurM',
#  'Flumioxazi',
#  'Oxamyl',
#  'Fénuron',
#  'Chlorthal',
#  'Benthiocar',
#  'FluazifopB',
#  'IsopropBzn',
#  'Pyridate',
#  'Antquinone',
#  'Hexazinone',
#  'Prométryne',
#  'Bromoxynil',
#  'DEA',
#  'Triasulfur',
#  'Methamidop']

# %%
df_caluire.dtypes
# Out:
# CdStationMesureEauxSurface     object
# LbStationMesureEauxSurface     object
# CdSupport                       int64
# LbSupport                      object
# CdFractionAnalysee              int64
# LbFractionAnalysee             object
# CdPrelevement                  object
# DatePrel                       object
# HeurePrel                      object
# DateAna                        object
# HeureAna                       object
# CdParametre                     int64
# LbLongParamètre                object
# RsAna                          object
# CdUniteMesure                  object
# SymUniteMesure                 object
# CdRqAna                         int64
# MnemoRqAna                     object
# CdInsituAna                     int64
# LbInsituAna                    object
# ProfondeurPrel                float64
# CdDifficulteAna                 int64
# MnemoDifficulteAna             object
# LdAna                         float64
# LqAna                         float64
# LsAna                         float64
# IncertAna                     float64
# CdMetFractionnement           float64
# NomMetFractionnement           object
# CdMethode                       int64
# NomMethode                     object
# RdtExtraction                 float64
# CdMethodeExtraction           float64
# NomMethodeExtraction           object
# CdAccreAna                      int64
# MnemoAccredAna                 object
# AgreAna                       float64
# CdStatutAna                     int64
# MnemoStatutAna                 object
# CdQualAna                       int64
# LbQualAna                      object
# CommentairesAna                object
# ComResultatAna                 object
# CdRdd                          object
# NomRdd                         object
# CdProducteur                    int64
# NomProducteur                  object
# CdPreleveur                   float64
# NomPreleveur                   object
# CdLaboratoire                 float64
# NomLaboratoire                 object
# dtype: object

# %%
df_caluire.DatePrel.unique()
# Out:
# array(['2005-03-02', '2005-05-11', '2005-06-15', '2005-04-13',
#        '2005-11-16', '2005-06-22', '2005-08-24', '2005-12-13',
#        '2005-01-19', '2005-11-30', '2005-10-12', '2005-09-06',
#        '2005-09-21', '2005-07-06', '2005-02-09', '2005-03-09',
#        '2005-08-17', '2005-09-23', '2005-10-20', '2005-05-25'],
#       dtype=object)

# %% [markdown]
# ## Should we take in consideration the data != 'eau' ?

# %%
df_caluire.CdFractionAnalysee.value_counts()
# Out:
# 23    6181
# 42    1283
# 32     449
# 3       78
# 61       8
# Name: CdFractionAnalysee, dtype: int64

# %%
df_caluire.LbSupport.value_counts()
# Out:
# Eau                                6259
# Matières en suspension (M.E.S.)    1283
# Sédiments                           449
# Bryophytes                            8
# Name: LbSupport, dtype: int64

# %%
df_caluire[df_caluire["LbSupport"] == "Matières en suspension (M.E.S.)"].head(20).LbLongParamètre.unique()
# Out:
# array(['Endosuf.a', 'DEHP', 'Cyprodinil', 'Pyrène', 'Alpha-cype',
#        '2ClToluène'], dtype=object)

# %%
LbLongP_df = df_2011_PC.LbLongParamètre.value_counts().to_frame()
LbLongP_df
# Out:
#                                                     LbLongParamètre
# Taux de saturation en oxygène                                    17
# Oxygène dissous                                                  17
# Conductivité à 25°C                                              17
# Potentiel en Hydrogène (pH)                                      17
# Température de l'Eau                                             17
# ...                                                             ...
# Manganèse                                                         1
# Fer                                                               1
# Aluminium                                                         1
# Somme Heptachlore époxyde cis/trans                               1
# Particules - Classe granulométrique : supérieur...                1
#
# [722 rows x 1 columns]

# %%
LbLongP_df[LbLongP_df.LbLongParamètre >= 12].reset_index()
# Out:
#                              index  LbLongParamètre
# 0    Taux de saturation en oxygène               17
# 1                  Oxygène dissous               17
# 2              Conductivité à 25°C               17
# 3      Potentiel en Hydrogène (pH)               17
# 4             Température de l'Eau               17
# ..                             ...              ...
# 160    Hexachlorocyclohexane alpha               12
# 161      Tricyclohexylétain cation               12
# 162     Hexachlorocyclohexane bêta               12
# 163    Hexachlorocyclohexane delta               12
# 164    Hexachlorocyclohexane gamma               12
#
# [165 rows x 2 columns]
